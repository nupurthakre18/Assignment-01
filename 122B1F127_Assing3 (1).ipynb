# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df= pd.read_csv('iris - iris.csv')
print(df)
# Out:
#      x0   x1   x2   x3   x4            type
# 0     1  5.1  3.5  1.4  0.2     Iris-setosa
# 1     1  4.9  3.0  1.4  0.2     Iris-setosa
# 2     1  4.7  3.2  1.3  0.2     Iris-setosa
# 3     1  4.6  3.1  1.5  0.2     Iris-setosa
# 4     1  5.0  3.6  1.4  0.2     Iris-setosa
# ..   ..  ...  ...  ...  ...             ...
# 145   1  6.7  3.0  5.2  2.3  Iris-virginica
# 146   1  6.3  2.5  5.0  1.9  Iris-virginica
# 147   1  6.5  3.0  5.2  2.0  Iris-virginica
# 148   1  6.2  3.4  5.4  2.3  Iris-virginica
# 149   1  5.9  3.0  5.1  1.8  Iris-virginica
#
# [150 rows x 6 columns]

# %%
df_numeric = df.drop(columns='type')
print(df_numeric)
# Out:
#      x0   x1   x2   x3   x4
# 0     1  5.1  3.5  1.4  0.2
# 1     1  4.9  3.0  1.4  0.2
# 2     1  4.7  3.2  1.3  0.2
# 3     1  4.6  3.1  1.5  0.2
# 4     1  5.0  3.6  1.4  0.2
# ..   ..  ...  ...  ...  ...
# 145   1  6.7  3.0  5.2  2.3
# 146   1  6.3  2.5  5.0  1.9
# 147   1  6.5  3.0  5.2  2.0
# 148   1  6.2  3.4  5.4  2.3
# 149   1  5.9  3.0  5.1  1.8
#
# [150 rows x 5 columns]

# %%
correlation_matrix = df_numeric.corr()

# %%
print("Correlation Matrix:")
print(correlation_matrix)
# Out:
# Correlation Matrix:
#     x0        x1        x2        x3        x4
# x0 NaN       NaN       NaN       NaN       NaN
# x1 NaN  1.000000 -0.109369  0.871754  0.817954
# x2 NaN -0.109369  1.000000 -0.420516 -0.356544
# x3 NaN  0.871754 -0.420516  1.000000  0.962757
# x4 NaN  0.817954 -0.356544  0.962757  1.000000

# %%
print(df.head())
print(df.columns)
# Out:
#    x0   x1   x2   x3   x4         type
# 0   1  5.1  3.5  1.4  0.2  Iris-setosa
# 1   1  4.9  3.0  1.4  0.2  Iris-setosa
# 2   1  4.7  3.2  1.3  0.2  Iris-setosa
# 3   1  4.6  3.1  1.5  0.2  Iris-setosa
# 4   1  5.0  3.6  1.4  0.2  Iris-setosa
# Index(['x0', 'x1', 'x2', 'x3', 'x4', 'type'], dtype='object')

# %%
df_numeric.head()
# Out:
#    x0   x1   x2   x3   x4
# 0   1  5.1  3.5  1.4  0.2
# 1   1  4.9  3.0  1.4  0.2
# 2   1  4.7  3.2  1.3  0.2
# 3   1  4.6  3.1  1.5  0.2
# 4   1  5.0  3.6  1.4  0.2

# %%
plt.figure(figsize=(8, 6))
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', fmt='.2f', linewidths=0.5)
# Out:
# <Axes: >

# %%
plt.plot([0, 1], [0, 1]) 
plt.title("Correlation Matrix of Iris Dataset")
plt.show()

# %%
sns.pairplot(df)
plt.suptitle('Pair Plot of IRIS Dataset', y=1.02)
plt.show()
